# %%
import pandas as pd
import altair as alt
from altair import datum

# %%
data = pd.read_csv('dataViz_formatted2.csv')
data.rename(columns={"Coverage subscore": "Coverage_SC", "Openness subscore": "Openness_SC", "Data categories": "Data_categories"}, inplace=True)
data
# Out:
#      Unnamed: 0  Unnamed: 0.1  Year     Country Country Code  \
# 0             0             0  2020      Cyprus          CYP
# 1             1             1  2020      Cyprus          CYP
# 2             2             2  2020      Cyprus          CYP
# 3             3             3  2020      Cyprus          CYP
# 4             4             4  2020      Cyprus          CYP
# ..          ...           ...   ...         ...          ...
# 697         697           697  2020  Luxembourg          LUX
# 698         698           698  2020  Luxembourg          LUX
# 699         699           699  2020  Luxembourg          LUX
# 700         700           700  2020  Luxembourg          LUX
# 701         701           701  2020  Luxembourg          LUX
#
#                    Data_categories  Indicator coverage and disaggregation  \
# 0    Population & vital statistics                                  100.0
# 1             Education facilities                                   50.0
# ...

# %%
data['Deviation'] = data['Coverage_SC'] - data['Openness_SC']
data['Deviation_norm'] = data['Deviation'] / abs(data['Deviation'])
data['Country'].unique().tolist()
# Out:
# ['Cyprus',
#  'Bulgaria',
#  'Czech Republic',
#  'Hungary',
#  'Poland',
#  'Romania',
#  'Slovakia',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'Ireland',
#  'Latvia',
#  'Lithuania',
#  'Sweden',
#  'Croatia',
#  'Greece',
#  'Italy',
#  'Malta',
#  'Portugal',
#  'Slovenia',
#  'Spain',
#  'Austria',
#  'Belgium',
#  'France',
#  'Germany',
#  'Netherlands',
#  'Luxembourg']

# %%
# Scatter Plot
points = alt.Chart(data).mark_point(filled=True).encode(
    x='Openness_SC:Q',
    y='Coverage_SC:Q',
    color=alt.Color('Deviation_norm:N', scale=alt.Scale(range=['red', 'blue'])),
    tooltip=['Country', 'Overall score', 'Coverage_SC', 'Openness_SC']
).transform_filter(
    (datum.Data_categories == 'All Categories')
)
points
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    x="Country:N",
    y="Deviation:Q",
    color=alt.condition(
        alt.datum.Deviation > 0,
        alt.value("steelblue"),  # The positive color
        alt.value("red")  # The negative color
    ),
    tooltip=['Country', 'Overall score', 'Coverage_SC', 'Openness_SC']
).transform_filter(
    (datum.Data_categories == 'All Categories')
)
# Out:
# alt.Chart(...)

# %%
countries = data['Country'].unique().tolist()
input_dropdown = alt.binding_select(options=countries, name='Country')
selection = alt.selection_single(fields=['Country'], bind=input_dropdown)
alt.Chart(data).mark_point(
    filled=True
).encode(
    x='Coverage_SC:Q',
    tooltip=['Country', 'Data_categories', 'Coverage_SC', 'Openness_SC']
).add_selection(
    selection
).transform_filter(
    selection
).properties(
    width=800
)
# Out:
# alt.Chart(...)
